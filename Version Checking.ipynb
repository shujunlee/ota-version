# %%
import pandas as pd
import numpy as np

df = pd.read_csv("devices_20210129_1621.csv", usecols = ['mdt_id','vehicle_id', 'list_of_app', 'rpt_time']) 

#Manually filter last report by latest date and remove the duplicated entries that has an older date
df['rpt_time'] =pd.to_datetime(df.rpt_time)
df.sort_values('rpt_time', ascending = False , inplace = True)

#trim vehicle plate whitespace
df['vehicle_id'] = df.vehicle_id.str.replace(' ', '')

df.set_index('vehicle_id')

#drop duplicated plate number
df.drop_duplicates(subset ="vehicle_id", 
                     keep = "first", inplace = True) 

#import vehicle master list
df_v = pd.read_csv("SMRT-master.csv", index_col = 'vehicle_id') 

df_smrt = pd.merge(df,  
                     df_v,  
                     on ='vehicle_id',  
                     how ='right') 
df_smrt
# Out:
#                mdt_id vehicle_id  \
# 0          SHB786K ID    SHB786K
# 1     864403045571834    SHF184B
# 2     861075023920630   SHC4533S
# 3     861075024188252   SHB5734C
# 4     861075023927445   SHC4759H
# ...               ...        ...
# 1795              NaN    SHF484K
# 1796              NaN    SHF493J
# 1797              NaN    SHF497Z
# 1798              NaN    SHF498X
# 1799              NaN    SHF499T
#
#                                             list_of_app            rpt_time  \
# 0     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 16:35:19
# 1     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 16:29:55
# 2     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 16:17:08
# 3     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 14:58:44
# 4     com.ucast.blackbox:1.0.1014.201027_RC,com.grab... 2021-12-01 14:18:28
# ...                                                 ...                 ...
# ...

# %%
#hired & on v28
df_smrt[(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) & (df_smrt['Hired Status'] == 'Hired')]
# Out:
#                mdt_id vehicle_id  \
# 0          SHB786K ID    SHB786K
# 1     864403045571834    SHF184B
# 3     861075024188252   SHB5734C
# 5     861075024179046   SHB5206K
# 8     861075024176034     SHF77C
# ...               ...        ...
# 1512  861075024187569    SHF412T
# 1514  861075023937188   SHC4655Z
# 1515  864403045569226   SHB5364L
# 1525  861075023926603   SHC4777E
# 1526  861075024176091    SHB903P
#
#                                             list_of_app            rpt_time  \
# 0     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 16:35:19
# 1     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 16:29:55
# 3     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 14:58:44
# 5     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-12-01 13:50:00
# 8     com.ucast.blackbox:1.0.1028.201216_RC,com.grab... 2021-11-01 15:43:26
# ...                                                 ...                 ...
# ...

# %%
#hired & not on v28
df_smrt[~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) & (df_smrt['Hired Status'] == 'Hired')]
# Out:
#                mdt_id vehicle_id  \
# 4     861075023927445   SHC4759H
# 6     861075023928716     SHF59E
# 9     861075024164378    SHB959D
# 20    861075023931660   SHD6277M
# 21    861075024163974   SHD6334G
# ...               ...        ...
# 1670              NaN      SHF2T
# 1671              NaN    SHF339Y
# 1672              NaN    SHF365X
# 1673              NaN    SHF477G
# 1674              NaN     SHF74K
#
#                                             list_of_app            rpt_time  \
# 4     com.ucast.blackbox:1.0.1014.201027_RC,com.grab... 2021-12-01 14:18:28
# 6     com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-12-01 10:24:19
# 9     com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-11-01 14:34:40
# 20    com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-08-01 22:41:25
# 21    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-08-01 20:13:51
# ...                                                 ...                 ...
# ...

# %%
#hired & not on v28 and has 2 ota client
df_smrt[~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) 
        & (df_smrt['Hired Status'] == 'Hired') 
        & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdmv2:1.0.15', na=False))
        & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdm:1', na=False))
       ]
# Out:
#                mdt_id vehicle_id  \
# 41    861075024188369   SHB5904D
# 44    861075023937907   SHC4703T
# 57    861075023924301   SHD6202D
# 74    861075024186454   SHB5705L
# 93    861075023934417     SHF30L
# ...               ...        ...
# 1467  861075023925027   SHC4022A
# 1500  861075024188377   SHB1728Y
# 1511  861075024194466    SHF209P
# 1513  861075024165706    SHB159X
# 1532  861075024176752   SHB5738S
#
#                                             list_of_app            rpt_time  \
# 41    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-05-01 15:41:33
# 44    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-05-01 01:30:28
# 57    com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-29 16:21:15
# 74    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-01-29 16:21:04
# 93    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-01-29 16:20:48
# ...                                                 ...                 ...
# ...

# %%
#hired & not on v28 and ota client v11
df_smrt[~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) 
        & (df_smrt['Hired Status'] == 'Hired') 
        & ~(df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdmv2:1.0.15', na=False))
        & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdm:1.0.11', na=False))
       ]
# Out:
#                mdt_id vehicle_id  \
# 4     861075023927445   SHC4759H
# 6     861075023928716     SHF59E
# 9     861075024164378    SHB959D
# 21    861075024163974   SHD6334G
# 32    861075024187866    SHB457K
# ...               ...        ...
# 1534  861075024163883   SHB5586M
# 1549  861075024182909   SHD6188L
# 1551  861075023922321   SHB1273S
# 1582  861075023930951   SHB5362S
# 1592  864403045568392   SHB1092Y
#
#                                             list_of_app            rpt_time  \
# 4     com.ucast.blackbox:1.0.1014.201027_RC,com.grab... 2021-12-01 14:18:28
# 6     com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-12-01 10:24:19
# 9     com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-11-01 14:34:40
# 21    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-08-01 20:13:51
# 32    com.ucast.blackbox:1.0.1021.201111_RC,com.grab... 2021-07-01 12:04:09
# ...                                                 ...                 ...
# ...

# %%
#hired & not on v28 and ota client v8
df_smrt[~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) 
        & (df_smrt['Hired Status'] == 'Hired') 
        & ~(df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdmv2:1.0.15', na=False))
        & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdm:1.0.8', na=False))
       ]
# Out:
#                mdt_id vehicle_id  \
# 20    861075023931660   SHD6277M
# 194   861075024178717    SHB135P
# 240   861075024163966   SHD6275T
# 750   861075023927411   SHD6417B
# 1372  861075023930167   SHB5805G
# 1375  861075023930415    SHF404S
# 1379  861075024188294   SHB5905B
# 1392  861075023932387    SHB137J
# 1473  864403045574341   SHB1209D
#
#                                             list_of_app            rpt_time  \
# 20    com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-08-01 22:41:25
# 194   com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-29 16:19:40
# 240   com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-29 16:19:09
# 750   com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-29 16:12:22
# 1372  com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-28 13:36:34
# 1375  com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-28 10:47:42
# 1379  com.ucast.blackbox:1.0.1017.201029_RC,com.grab... 2021-01-28 04:44:18
# ...

# %%
#hired & not on v28 and ota client v7
df_smrt[~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) 
        & (df_smrt['Hired Status'] == 'Hired') 
        & ~(df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdmv2:1.0.15', na=False))
        & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdm:1.0.7', na=False))
       ]
df.to_csv('test.csv', index=False)

# %%
#df_smrt['list_of_app'].str.split(',')

# %%
df_smrt['list_of_app'][0].split(',')
# Out:
# ['com.ucast.blackbox:1.0.1028.201216_RC',
#  'com.grab.blackboxtest:1.0',
#  'com.ste.itsd.fms.agilmdm:1.0.7',
#  'com.grab.tex:20.42.0-522d2fe',
#  'com.ucast.blackboxlog:3.0']

# %%
#loop through the df and extract only the vehicle and meter/tariff firmware data. exclude the list of software
for i in range(len(df_smrt['list_of_app'])):
    if (df_smrt['Hired Status'][i] == 'Hired') & ('meter.firmware::610' in df_smrt['list_of_app'][i]):
        print(i)
        
#(df_smrt['list_of_app'][i].contains('meter.firmware::610', na=False)) &

'meter.firmware::610' in df_smrt['list_of_app'][1230]
# Out:
# 1
# 3
# 4
# 5
# 6
# 8
# 9
# 11
# 12
# 17
# 18
# 20
# 21
# 32
# 34
# 37
# 41
# 44
# 45
# 47
# 51
# 53
# 54
# 57
# 58
# 59
# 60
# 62
# 63
# 64
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 78
# 80
# 81
# 82
# 83
# 84
# 85
# 87
# 88
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 115
# 116
# 117
# 118
# 119
# 121
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 133
# 134
# 135
# 136
# 137
# 138
# 139
# 140
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 154
# 155
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 181
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 192
# 193
# 194
# 195
# 196
# 197
# 199
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 212
# 213
# 215
# 216
# 217
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 235
# ...

# %%
~(df_smrt['list_of_app'].str.contains('com.ucast.blackbox:1.0.1028.201216_RC', na=False)) & (df_smrt['Hired Status'] == 'Hired') & ~(df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdmv2:1.0.15', na=False)) & (df_smrt['list_of_app'].str.contains('com.ste.itsd.fms.agilmdm:1.0.7', na=False))

# %%
#filter
df_a = df_smrt[(df_smrt['list_of_app'].str.contains('tariff.firmware', na=False))]

#new dict to store just vehicle and meter/tariff data
vehicle = {}
for i in df_a.index:
    if df_a['list_of_app'][i] == None:
        vehicle[df_a['vehicle_id'][i]] = 'NA'
    else:
        vehicle[df_a['vehicle_id'][i]] = df_a['list_of_app'][i].split(',')[-2:]


df_tariff = pd.DataFrame.from_dict(vehicle, orient='index');
df_tariff
df_tariff.to_csv('tariff.csv')

# %% [raw]
# df_b = df_smrt[(df_smrt['list_of_app'].str.contains('tariff.firmware::24635', na=False))]
# df_b

# %%
df_a
